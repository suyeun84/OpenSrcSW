# %%
class Point:
    a=input("값 2개를 입력하세요").split(" ")
# Out:
#   File "<ipython-input-12-5a66b696d3c2>", line 3
#     array[]=a
#           ^
# SyntaxError: invalid syntax

# %%
import csv
f=open('seoul.csv','r',encoding='cp949')
data=csv.reader(f)

next(data)
header=next(data)
max_temp=min_temp=0
MaxWeek=''

lowtemp=float(header[1])
hightemp=float(header[2])
daily=hightemp-lowtemp
dailydate=header[0]

for row in data:
    row[-1]=float(row[-1])
    dailytemp[31]=float(row[2])-float(row[1])
    
while i<25:
    i, j=0
    Week[j]=dailytemp[i]+dailytemp[i+1]+dailytemp[i+2]+dailytemp[i+3]+dailytemp[i+4]+dailytemp[i+5]+dailytemp[i+6]
    i++
    j++

if(Week[0]>Week[1]&&Week[0]>Week[2]&&Week[0]>Week[3]&&Week[0]>Week[4]&&Week[0]>Week[5]&&Week[0]>Week[6]):
    print("Max Week= 5/{0:}~ 5/{1:}".format(i+1,i+8))
if(Week[1]>Week[1]&&Week[]>Week[2]&&Week[0]>Week[3]&&Week[0]>Week[4]&&Week[0]>Week[5]&&Week[0]>Week[6]):
    print("Max Week= 5/{0:}~ 5/{1:}".format(i+1,i+8))
if(Week[2]>Week[1]&&Week[0]>Week[2]&&Week[0]>Week[3]&&Week[0]>Week[4]&&Week[0]>Week[5]&&Week[0]>Week[6]):
    print("Max Week= 5/{0:}~ 5/{1:}".format(i+1,i+8))
if(Week[3]>Week[1]&&Week[0]>Week[2]&&Week[0]>Week[3]&&Week[0]>Week[4]&&Week[0]>Week[5]&&Week[0]>Week[6]):
    print("Max Week= 5/{0:}~ 5/{1:}".format(i+1,i+8))
if(Week[4]>Week[1]&&Week[0]>Week[2]&&Week[0]>Week[3]&&Week[0]>Week[4]&&Week[0]>Week[5]&&Week[0]>Week[6]):
    print("Max Week= 5/{0:}~ 5/{1:}".format(i+1,i+8))
if(Week[5]>Week[1]&&Week[0]>Week[2]&&Week[0]>Week[3]&&Week[0]>Week[4]&&Week[0]>Week[5]&&Week[0]>Week[6]):
    print("Max Week= 5/{0:}~ 5/{1:}".format(i+1,i+8))
if(Week[6]>Week[1]&&Week[0]>Week[2]&&Week[0]>Week[3]&&Week[0]>Week[4]&&Week[0]>Week[5]&&Week[0]>Week[6]):
    print("Max Week= 5/{0:}~ 5/{1:}".format(i+1,i+8))
f.close()
# Out:
# 2021-05-14
# -
# -
