# %%
#실습문제1번
x=int(input("x값을 입력하세요:"))
print("y=",3*x*x+5*x+3)
# Out:
# x값을 입력하세요:10
# y= 353

# %%
#실습문제2번
pi=3.14
r=int(input("원의 반지름을 입력하세요:"))
str="원의 둘레: {0:.2f}\n원의 넓이: {1:.2f}".format(2*pi*r,pi*r*r)
print(str)
# Out:
# 원의 반지름을 입력하세요:7
# 원의 둘레: 43.96
# 원의 넓이: 153.86
